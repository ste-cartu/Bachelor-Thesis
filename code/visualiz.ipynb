# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pkz = np.load('../files/prova_pkz.npy')
tf2 = np.load('../files/prova_tf2.npy')
prim = np.load('../files/prova_prim.npy')
mu2 = np.load('../files/prova_mu2.npy')
kk = np.load('../files/prova_kk.npy')
zz = np.load('../files/prova_zz.npy')

# %%
print(mu2)
# Out:
# [[1.         0.98479565 0.97080814 ... 0.8584083  0.85521917 0.85238193]
#  [1.         0.98479591 0.97080865 ... 0.85841059 0.85522151 0.85238431]
#  [1.         0.98479621 0.97080922 ... 0.85841314 0.8552241  0.85238695]
#  ...
#  [1.         0.99966506 0.99935145 ... 0.99660318 0.99651743 0.99644051]
#  [1.         0.99977877 0.99957159 ... 0.99775485 0.99769812 0.99764723]
#  [1.         0.99986036 0.99972958 ... 0.99858217 0.99854633 0.99851417]]

# %%
plt.plot(zz, mu2[0,:])
plt.plot(zz, mu2[-1,:])
#plt.plot(zz, mu2[-1,:]/mu2[0,:])
plt.show()

# %%
data = np.load('../files/data_VBCh_[100,20,comb=200].npy')
data
# Out:
# array([[1.65176203e-02, 7.80310201e-05, 0.00000000e+00, ...,
#         2.44486508e-01, 7.80310201e-01, 1.00000000e+00],
#        [1.65176203e-02, 7.80310201e-05, 2.63157895e-01, ...,
#         2.44486508e-01, 7.80310201e-01, 9.95292569e-01],
#        [1.65176203e-02, 7.80310201e-05, 5.26315789e-01, ...,
#         2.44486508e-01, 7.80310201e-01, 9.90711261e-01],
#        ...,
#        [1.48522559e-02, 2.27966615e+00, 4.47368421e+00, ...,
#         2.40438625e-01, 7.59888716e-01, 9.99173565e-01],
#        [1.48522559e-02, 2.27966615e+00, 4.73684211e+00, ...,
#         2.40438625e-01, 7.59888716e-01, 9.99164293e-01],
#        [1.48522559e-02, 2.27966615e+00, 5.00000000e+00, ...,
#         2.40438625e-01, 7.59888716e-01, 9.99155794e-01]])

# %%
plt.loglog(kk, tf2)
plt.show()

# %%
plt.loglog(kk, prim)
plt.show()
